# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Define variables for columns
City=[]
Lat=[]
Lng=[]
Max_Temp=[]
Humidity=[]
Cloudiness=[]
Wind_Speed=[]
Country=[]
Date=[]

# %%
#Define URL for API call
pre_url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=Imperial&q="

# %%
#Print headings
print("Beginning Data Retrieval")
print("-----------------------------")

#Iterate through cities to retrieve data
r=0
s=1
for city in cities:
    
    try:
            r += 1
            print(f"Processing Record {r} of Set {s} | {city}")
            call = requests.get(pre_url + city).json()
            City.append(call['name'])
            Lat.append(call['coord']['lat'])
            Lng.append(call['coord']['lon'])
            Max_Temp.append(call['main']['temp_max'])            
            Humidity.append(call['main']['humidity'])            
            Cloudiness.append(call['clouds']['all'])
            Wind_Speed.append(call['wind']['speed'])
            Country.append(call['sys']['country'])
            Date.append(call['dt'])
           
    except:
        print("City not found. Skipping...")
            
    if r == 50:
        s += 1
        r = 0
                
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaeo
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | gat
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | benjamin hill
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | havre-saint-pierre
# Processing Record 11 of Set 1 | maningrida
# Processing Record 12 of Set 1 | iquitos
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 1 | pokhara
# Processing Record 18 of Set 1 | saint anthony
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | buraydah
# Processing Record 22 of Set 1 | berlevag
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | conceicao do araguaia
# Processing Record 31 of Set 1 | kolosovka
# Processing Record 32 of Set 1 | praia
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | beringen
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | pochutla
# Processing Record 39 of Set 1 | khartoum
# Processing Record 40 of Set 1 | namibe
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | ponta do sol
# Processing Record 43 of Set 1 | angra
# City not found. Skipping...
# Processing Record 44 of Set 1 | mandurah
# Processing Record 45 of Set 1 | domoni
# Processing Record 46 of Set 1 | aksu
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | najran
# Processing Record 50 of Set 1 | lata
# Processing Record 1 of Set 2 | coquimbo
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | kupang
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | zhanakorgan
# Processing Record 6 of Set 2 | yertsevo
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 2 | dingle
# Processing Record 13 of Set 2 | malaut
# Processing Record 14 of Set 2 | mantua
# Processing Record 15 of Set 2 | aklavik
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | mango
# Processing Record 23 of Set 2 | necochea
# Processing Record 24 of Set 2 | pilani
# Processing Record 25 of Set 2 | dabhol
# Processing Record 26 of Set 2 | bela palanka
# Processing Record 27 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 2 | longhua
# Processing Record 29 of Set 2 | pisco
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | iranshahr
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | daru
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | yermekeyevo
# Processing Record 37 of Set 2 | edd
# Processing Record 38 of Set 2 | finschhafen
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | la serena
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | sam chuk
# Processing Record 46 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 2 | berezovyy
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | carutapera
# Processing Record 50 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 3 | sistranda
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | xichang
# Processing Record 5 of Set 3 | hasaki
# Processing Record 6 of Set 3 | hobart
# Processing Record 7 of Set 3 | srednekolymsk
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | dhidhdhoo
# Processing Record 11 of Set 3 | anchorage
# Processing Record 12 of Set 3 | ndago
# Processing Record 13 of Set 3 | bathsheba
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | owensboro
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | thinadhoo
# Processing Record 18 of Set 3 | mweka
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | benguela
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | sibut
# Processing Record 24 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | sambava
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | marzuq
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | provideniya
# Processing Record 30 of Set 3 | kasane
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | muros
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | sechura
# Processing Record 35 of Set 3 | vanimo
# Processing Record 36 of Set 3 | myitkyina
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | vigrestad
# Processing Record 39 of Set 3 | totana
# Processing Record 40 of Set 3 | agboville
# Processing Record 41 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | mount isa
# Processing Record 44 of Set 3 | norman wells
# Processing Record 45 of Set 3 | bundu
# Processing Record 46 of Set 3 | bud
# Processing Record 47 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 48 of Set 3 | green river
# Processing Record 49 of Set 3 | codrington
# Processing Record 50 of Set 3 | jashpurnagar
# Processing Record 1 of Set 4 | noumea
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | kargil
# Processing Record 4 of Set 4 | acarau
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | paamiut
# Processing Record 7 of Set 4 | lorengau
# Processing Record 8 of Set 4 | boralday
# Processing Record 9 of Set 4 | sarangani
# Processing Record 10 of Set 4 | sabha
# Processing Record 11 of Set 4 | rio grande
# Processing Record 12 of Set 4 | jenks
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | egvekinot
# Processing Record 16 of Set 4 | saint-francois
# Processing Record 17 of Set 4 | abonnema
# Processing Record 18 of Set 4 | souillac
# Processing Record 19 of Set 4 | champerico
# Processing Record 20 of Set 4 | talnakh
# Processing Record 21 of Set 4 | wadi maliz
# Processing Record 22 of Set 4 | ngunguru
# Processing Record 23 of Set 4 | never
# Processing Record 24 of Set 4 | deep river
# Processing Record 25 of Set 4 | kruisfontein
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | manbij
# Processing Record 28 of Set 4 | heihe
# Processing Record 29 of Set 4 | khandyga
# Processing Record 30 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 4 | sorland
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | roald
# Processing Record 36 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 4 | ahipara
# Processing Record 38 of Set 4 | carndonagh
# Processing Record 39 of Set 4 | san cristobal
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | parauna
# Processing Record 44 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 4 | port hedland
# Processing Record 46 of Set 4 | chimoio
# Processing Record 47 of Set 4 | waingapu
# Processing Record 48 of Set 4 | plover
# Processing Record 49 of Set 4 | kaspiyskiy
# Processing Record 50 of Set 4 | faya
# Processing Record 1 of Set 5 | orlik
# Processing Record 2 of Set 5 | cabo rojo
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | avarua
# Processing Record 5 of Set 5 | stromness
# Processing Record 6 of Set 5 | cidreira
# Processing Record 7 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 5 | samarai
# Processing Record 9 of Set 5 | deputatskiy
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | lyubim
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | cap-aux-meules
# Processing Record 14 of Set 5 | saint-joseph
# Processing Record 15 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 5 | ormara
# Processing Record 17 of Set 5 | amapa
# Processing Record 18 of Set 5 | te anau
# Processing Record 19 of Set 5 | paso de patria
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | minot
# Processing Record 22 of Set 5 | iracoubo
# Processing Record 23 of Set 5 | longyan
# Processing Record 24 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 25 of Set 5 | carnarvon
# Processing Record 26 of Set 5 | miri
# Processing Record 27 of Set 5 | dharchula
# Processing Record 28 of Set 5 | seoul
# Processing Record 29 of Set 5 | baiyin
# Processing Record 30 of Set 5 | aswan
# Processing Record 31 of Set 5 | eyl
# Processing Record 32 of Set 5 | vitrolles
# Processing Record 33 of Set 5 | maltahohe
# Processing Record 34 of Set 5 | aguas belas
# Processing Record 35 of Set 5 | ilulissat
# Processing Record 36 of Set 5 | sabang
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | gamba
# Processing Record 40 of Set 5 | huambo
# Processing Record 41 of Set 5 | leh
# Processing Record 42 of Set 5 | yambio
# Processing Record 43 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 5 | zhangye
# Processing Record 45 of Set 5 | dubbo
# Processing Record 46 of Set 5 | hede
# Processing Record 47 of Set 5 | bambamarca
# Processing Record 48 of Set 5 | viedma
# Processing Record 49 of Set 5 | khromtau
# Processing Record 50 of Set 5 | shiyan
# Processing Record 1 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 6 | ulladulla
# Processing Record 4 of Set 6 | peniche
# Processing Record 5 of Set 6 | smithers
# Processing Record 6 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 6 | khatanga
# Processing Record 8 of Set 6 | tigzirt
# Processing Record 9 of Set 6 | dawlatabad
# Processing Record 10 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 6 | severo-yeniseyskiy
# Processing Record 12 of Set 6 | coihaique
# Processing Record 13 of Set 6 | antalaha
# Processing Record 14 of Set 6 | andros town
# Processing Record 15 of Set 6 | nyurba
# Processing Record 16 of Set 6 | ixtapa
# Processing Record 17 of Set 6 | pangoa
# Processing Record 18 of Set 6 | awka
# Processing Record 19 of Set 6 | svetlogorsk
# Processing Record 20 of Set 6 | cairns
# Processing Record 21 of Set 6 | lumeje
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | birjand
# Processing Record 24 of Set 6 | chuy
# Processing Record 25 of Set 6 | houston
# Processing Record 26 of Set 6 | athabasca
# Processing Record 27 of Set 6 | arteaga
# Processing Record 28 of Set 6 | camocim
# Processing Record 29 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 6 | eloi mendes
# Processing Record 31 of Set 6 | pangai
# Processing Record 32 of Set 6 | yamada
# Processing Record 33 of Set 6 | alofi
# Processing Record 34 of Set 6 | tilichiki
# Processing Record 35 of Set 6 | njeru
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | ankazoabo
# Processing Record 38 of Set 6 | panalingaan
# Processing Record 39 of Set 6 | povarovo
# Processing Record 40 of Set 6 | pevek
# Processing Record 41 of Set 6 | kieta
# Processing Record 42 of Set 6 | bahia honda
# Processing Record 43 of Set 6 | mayo
# Processing Record 44 of Set 6 | stepnyak
# Processing Record 45 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 6 | narsaq
# Processing Record 47 of Set 6 | rosario do sul
# Processing Record 48 of Set 6 | ghanzi
# Processing Record 49 of Set 6 | mount gambier
# Processing Record 50 of Set 6 | chernyshevskiy
# Processing Record 1 of Set 7 | kenai
# Processing Record 2 of Set 7 | abu zabad
# Processing Record 3 of Set 7 | nong khae
# Processing Record 4 of Set 7 | koygorodok
# Processing Record 5 of Set 7 | hibbing
# Processing Record 6 of Set 7 | grand forks
# Processing Record 7 of Set 7 | anantapur
# Processing Record 8 of Set 7 | duz
# City not found. Skipping...
# Processing Record 9 of Set 7 | lillesand
# Processing Record 10 of Set 7 | ferrol
# Processing Record 11 of Set 7 | belo oriente
# Processing Record 12 of Set 7 | port shepstone
# Processing Record 13 of Set 7 | jalu
# Processing Record 14 of Set 7 | henties bay
# Processing Record 15 of Set 7 | port-cartier
# Processing Record 16 of Set 7 | maniitsoq
# Processing Record 17 of Set 7 | hami
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | northam
# Processing Record 20 of Set 7 | tahe
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | arys
# Processing Record 23 of Set 7 | fukue
# Processing Record 24 of Set 7 | batangafo
# Processing Record 25 of Set 7 | tuatapere
# Processing Record 26 of Set 7 | atbasar
# Processing Record 27 of Set 7 | zhigansk
# Processing Record 28 of Set 7 | ostrovnoy
# Processing Record 29 of Set 7 | prado
# Processing Record 30 of Set 7 | manoharpur
# Processing Record 31 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 7 | kongsvinger
# Processing Record 33 of Set 7 | batticaloa
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | qaqortoq
# Processing Record 36 of Set 7 | totness
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | brae
# Processing Record 39 of Set 7 | namatanai
# Processing Record 40 of Set 7 | tasiilaq
# Processing Record 41 of Set 7 | rubiataba
# Processing Record 42 of Set 7 | ambulu
# Processing Record 43 of Set 7 | acucena
# Processing Record 44 of Set 7 | melfi
# Processing Record 45 of Set 7 | olafsvik
# Processing Record 46 of Set 7 | rawson
# Processing Record 47 of Set 7 | zelenoborskiy
# Processing Record 48 of Set 7 | ada
# Processing Record 49 of Set 7 | gangtok
# Processing Record 50 of Set 7 | adrar
# Processing Record 1 of Set 8 | kovdor
# Processing Record 2 of Set 8 | mabaruma
# Processing Record 3 of Set 8 | victoria
# Processing Record 4 of Set 8 | kununurra
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | stralsund
# Processing Record 7 of Set 8 | cockburn town
# Processing Record 8 of Set 8 | jadu
# Processing Record 9 of Set 8 | nishiwaki
# Processing Record 10 of Set 8 | benghazi
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 8 | novo aripuana
# Processing Record 14 of Set 8 | trairi
# Processing Record 15 of Set 8 | hlyboka
# Processing Record 16 of Set 8 | chisec
# Processing Record 17 of Set 8 | broken hill
# Processing Record 18 of Set 8 | talaya
# Processing Record 19 of Set 8 | esperance
# Processing Record 20 of Set 8 | aykhal
# Processing Record 21 of Set 8 | puerto escondido
# Processing Record 22 of Set 8 | praia da vitoria
# Processing Record 23 of Set 8 | boyolangu
# Processing Record 24 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 8 | maine-soroa
# Processing Record 26 of Set 8 | haines junction
# Processing Record 27 of Set 8 | nome
# Processing Record 28 of Set 8 | cognac
# Processing Record 29 of Set 8 | klyuchi
# Processing Record 30 of Set 8 | bambous virieux
# Processing Record 31 of Set 8 | kichmengskiy gorodok
# Processing Record 32 of Set 8 | tanete
# Processing Record 33 of Set 8 | the valley
# Processing Record 34 of Set 8 | westport
# Processing Record 35 of Set 8 | chakulia
# Processing Record 36 of Set 8 | aguimes
# Processing Record 37 of Set 8 | banda aceh
# Processing Record 38 of Set 8 | itanagar
# Processing Record 39 of Set 8 | salalah
# Processing Record 40 of Set 8 | kudahuvadhoo
# Processing Record 41 of Set 8 | maraa
# Processing Record 42 of Set 8 | sokoto
# Processing Record 43 of Set 8 | dneprovskaya
# Processing Record 44 of Set 8 | southbridge
# Processing Record 45 of Set 8 | hobyo
# Processing Record 46 of Set 8 | vurnary
# Processing Record 47 of Set 8 | ewa beach
# Processing Record 48 of Set 8 | assiniboia
# Processing Record 49 of Set 8 | airai
# Processing Record 50 of Set 8 | placido de castro
# Processing Record 1 of Set 9 | sept-iles
# Processing Record 2 of Set 9 | ducheng
# Processing Record 3 of Set 9 | dabakala
# Processing Record 4 of Set 9 | vardo
# Processing Record 5 of Set 9 | sorong
# Processing Record 6 of Set 9 | yumbing
# Processing Record 7 of Set 9 | loudi
# Processing Record 8 of Set 9 | padang
# Processing Record 9 of Set 9 | mamakan
# Processing Record 10 of Set 9 | acurenam
# Processing Record 11 of Set 9 | north bend
# Processing Record 12 of Set 9 | salinas
# Processing Record 13 of Set 9 | troitskoye
# Processing Record 14 of Set 9 | goiatuba
# Processing Record 15 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 9 | hwange
# Processing Record 17 of Set 9 | tanout
# Processing Record 18 of Set 9 | poum
# Processing Record 19 of Set 9 | ucluelet
# Processing Record 20 of Set 9 | cape canaveral
# Processing Record 21 of Set 9 | araruna
# Processing Record 22 of Set 9 | hirara
# Processing Record 23 of Set 9 | fairbanks
# Processing Record 24 of Set 9 | kargasok
# Processing Record 25 of Set 9 | grindavik
# Processing Record 26 of Set 9 | axim
# Processing Record 27 of Set 9 | pagondas
# City not found. Skipping...
# Processing Record 28 of Set 9 | mareeba
# Processing Record 29 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 30 of Set 9 | kokoda
# Processing Record 31 of Set 9 | togur
# Processing Record 32 of Set 9 | noyabrsk
# Processing Record 33 of Set 9 | krasnoarmeysk
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | jinchang
# Processing Record 36 of Set 9 | grand gaube
# Processing Record 37 of Set 9 | allonnes
# Processing Record 38 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 9 | lima
# Processing Record 40 of Set 9 | baykit
# Processing Record 41 of Set 9 | usakos
# Processing Record 42 of Set 9 | nhulunbuy
# Processing Record 43 of Set 9 | college
# Processing Record 44 of Set 9 | noshiro
# Processing Record 45 of Set 9 | chumikan
# Processing Record 46 of Set 9 | khandbari
# Processing Record 47 of Set 9 | atar
# Processing Record 48 of Set 9 | iringa
# Processing Record 49 of Set 9 | rocha
# Processing Record 50 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 10 | harwich
# Processing Record 2 of Set 10 | nerchinskiy zavod
# Processing Record 3 of Set 10 | hofn
# Processing Record 4 of Set 10 | goderich
# Processing Record 5 of Set 10 | carauari
# Processing Record 6 of Set 10 | hays
# Processing Record 7 of Set 10 | mnogovershinnyy
# Processing Record 8 of Set 10 | kavaratti
# Processing Record 9 of Set 10 | puerto maldonado
# Processing Record 10 of Set 10 | belyy yar
# Processing Record 11 of Set 10 | shenjiamen
# Processing Record 12 of Set 10 | xining
# Processing Record 13 of Set 10 | mana
# Processing Record 14 of Set 10 | tsaratanana
# Processing Record 15 of Set 10 | beisfjord
# Processing Record 16 of Set 10 | gambo
# Processing Record 17 of Set 10 | hamilton
# Processing Record 18 of Set 10 | wagar
# Processing Record 19 of Set 10 | whitianga
# Processing Record 20 of Set 10 | sao francisco
# Processing Record 21 of Set 10 | chapais
# Processing Record 22 of Set 10 | novi sanzhary
# Processing Record 23 of Set 10 | glomfjord
# Processing Record 24 of Set 10 | caravelas
# Processing Record 25 of Set 10 | marolambo
# Processing Record 26 of Set 10 | comodoro rivadavia
# Processing Record 27 of Set 10 | videira
# Processing Record 28 of Set 10 | conakry
# Processing Record 29 of Set 10 | dubrovka
# Processing Record 30 of Set 10 | vila velha
# Processing Record 31 of Set 10 | palatka
# Processing Record 32 of Set 10 | high rock
# Processing Record 33 of Set 10 | salinopolis
# Processing Record 34 of Set 10 | chaihe
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | marataizes
# Processing Record 37 of Set 10 | batsfjord
# Processing Record 38 of Set 10 | aracuai
# Processing Record 39 of Set 10 | londoko
# Processing Record 40 of Set 10 | wuning
# Processing Record 41 of Set 10 | komsomolets
# Processing Record 42 of Set 10 | manoel urbano
# Processing Record 43 of Set 10 | rio gallegos
# Processing Record 44 of Set 10 | tessalit
# Processing Record 45 of Set 10 | yangjiang
# Processing Record 46 of Set 10 | porto walter
# Processing Record 47 of Set 10 | san quintin
# Processing Record 48 of Set 10 | saskylakh
# Processing Record 49 of Set 10 | tolmezzo
# Processing Record 50 of Set 10 | husavik
# Processing Record 1 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 11 | plainview
# Processing Record 3 of Set 11 | lara
# Processing Record 4 of Set 11 | bom jesus
# Processing Record 5 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 11 | aranos
# Processing Record 7 of Set 11 | werota
# Processing Record 8 of Set 11 | san buenaventura
# Processing Record 9 of Set 11 | eureka
# Processing Record 10 of Set 11 | pombal
# Processing Record 11 of Set 11 | saldanha
# Processing Record 12 of Set 11 | indianola
# Processing Record 13 of Set 11 | broome
# Processing Record 14 of Set 11 | keetmanshoop
# Processing Record 15 of Set 11 | roma
# Processing Record 16 of Set 11 | moyale
# Processing Record 17 of Set 11 | coos bay
# Processing Record 18 of Set 11 | gladstone
# Processing Record 19 of Set 11 | thunder bay
# Processing Record 20 of Set 11 | nantucket
# Processing Record 21 of Set 11 | atasu
# Processing Record 22 of Set 11 | luyang
# Processing Record 23 of Set 11 | srikakulam
# Processing Record 24 of Set 11 | phalombe
# Processing Record 25 of Set 11 | pappinisseri
# Processing Record 26 of Set 11 | black forest
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 29 of Set 11 | saint george
# Processing Record 30 of Set 11 | ratnagiri
# Processing Record 31 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | bagotville
# Processing Record 33 of Set 11 | dalinghe
# City not found. Skipping...
# Processing Record 34 of Set 11 | arlit
# Processing Record 35 of Set 11 | bengkulu
# Processing Record 36 of Set 11 | tucuman
# Processing Record 37 of Set 11 | podgorica
# Processing Record 38 of Set 11 | poya
# Processing Record 39 of Set 11 | udachnyy
# Processing Record 40 of Set 11 | yibin
# Processing Record 41 of Set 11 | yanam
# Processing Record 42 of Set 11 | luganville
# Processing Record 43 of Set 11 | vuktyl
# Processing Record 44 of Set 11 | rokytne
# Processing Record 45 of Set 11 | lazaro cardenas
# Processing Record 46 of Set 11 | riachao das neves
# Processing Record 47 of Set 11 | blackwater
# Processing Record 48 of Set 11 | nanortalik
# Processing Record 49 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 11 | chiredzi
# Processing Record 1 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 12 | port hardy
# Processing Record 3 of Set 12 | zyryanka
# Processing Record 4 of Set 12 | kananga
# Processing Record 5 of Set 12 | trincomalee
# Processing Record 6 of Set 12 | rio brilhante
# Processing Record 7 of Set 12 | myaundzha
# Processing Record 8 of Set 12 | nisia floresta
# Processing Record 9 of Set 12 | teya
# Processing Record 10 of Set 12 | chalus
# Processing Record 11 of Set 12 | ambilobe
# Processing Record 12 of Set 12 | pontes e lacerda
# Processing Record 13 of Set 12 | hambantota
# Processing Record 14 of Set 12 | xanxere
# Processing Record 15 of Set 12 | isangel
# Processing Record 16 of Set 12 | natal
# Processing Record 17 of Set 12 | jurado
# Processing Record 18 of Set 12 | aden
# Processing Record 19 of Set 12 | bara
# Processing Record 20 of Set 12 | porto novo
# Processing Record 21 of Set 12 | penzberg
# Processing Record 22 of Set 12 | tucupita
# Processing Record 23 of Set 12 | zolochiv
# Processing Record 24 of Set 12 | vestmannaeyjar
# Processing Record 25 of Set 12 | taoudenni
# Processing Record 26 of Set 12 | miedzyrzec podlaski
# Processing Record 27 of Set 12 | clyde river
# Processing Record 28 of Set 12 | zhob
# Processing Record 29 of Set 12 | balabac
# Processing Record 30 of Set 12 | shimoda
# Processing Record 31 of Set 12 | olhao
# Processing Record 32 of Set 12 | arman
# Processing Record 33 of Set 12 | kharian
# Processing Record 34 of Set 12 | passy
# Processing Record 35 of Set 12 | letlhakane
# Processing Record 36 of Set 12 | uruzgan
# Processing Record 37 of Set 12 | hohhot
# Processing Record 38 of Set 12 | kokopo
# Processing Record 39 of Set 12 | paracuru
# Processing Record 40 of Set 12 | mahibadhoo
# Processing Record 41 of Set 12 | hukuntsi
# Processing Record 42 of Set 12 | atambua
# Processing Record 43 of Set 12 | maceio
# Processing Record 44 of Set 12 | middle island
# Processing Record 45 of Set 12 | yunjinghong
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df=pd.DataFrame({"City":City, "Lat":Lat,"Lng":Lng, "Max Temp": Max_Temp, "Humidity": Humidity, "Cloudiness": Cloudiness, 
                        "Wind Speed": Wind_Speed, "Country": Country, "Date": Date})

weather_csv=weather_df.to_csv("weather.csv", header = True)
weather_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kaeo -35.1000  173.7833     69.01        97         100        8.99
# 1    Yar-Sale  66.8333   70.8333    -29.18        85           5        4.12
# 2   Busselton -33.6500  115.3333     84.00        41           2        3.00
# 3  Kiryat Gat  31.6100   34.7642     51.01        87           0        2.30
# 4     Rikitea -23.1203 -134.9692     79.74        75          99       10.54
#
#   Country        Date
# 0      NZ  1613272235
# 1      RU  1613272492
# 2      AU  1613272397
# 3      IL  1613272441
# 4      PF  1613272400

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    18.732703   17.505861   49.961389   74.712980   54.853748    7.635777
# std     33.226579   88.261846   31.962376   18.467769   41.386021    5.859020
# min    -54.800000 -179.166700  -32.010000   18.000000    0.000000    0.400000
# 25%     -9.384050  -56.937100   26.600000   66.000000    2.500000    3.440000
# 50%     22.075200   19.263600   64.000000   79.000000   71.000000    6.130000
# 75%     47.404650   90.003500   74.820000   88.000000   98.000000   10.660000
# max     78.218600  178.416700   91.400000  100.000000  100.000000   42.570000
#
#                Date
# count  5.470000e+02
# mean   1.613273e+09
# std    8.668296e+01
# min    1.613272e+09
# 25%    1.613272e+09
# 50%    1.613273e+09
# 75%    1.613273e+09
# max    1.613273e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#It does not apply because the Humidity max is 100 
#Filter Humidity to find out if there are any cities with humidity greater than 100%
weather_df[weather_df["Humidity"]>100].head()
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  There are no cities that have humidity over 100% only 100% and below.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Determine outliers using upper and lower bounds
humidity = weather_df["Humidity"]
lowerq = humidity.quantile(.25)
upperq = humidity.quantile(.75)
IQR = upperq - lowerq
lowerb = lowerq - (1.5*IQR)
upperb = upperq + (1.5*IQR)
clean_city_data = (weather_df[(weather_df["Humidity"] >= lowerb) | (weather_df["Humidity"] <= upperb)])
clean_city_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Kaeo -35.1000  173.7833     69.01        97         100        8.99
# 1    Yar-Sale  66.8333   70.8333    -29.18        85           5        4.12
# 2   Busselton -33.6500  115.3333     84.00        41           2        3.00
# 3  Kiryat Gat  31.6100   34.7642     51.01        87           0        2.30
# 4     Rikitea -23.1203 -134.9692     79.74        75          99       10.54
#
#   Country        Date
# 0      NZ  1613272235
# 1      RU  1613272492
# 2      AU  1613272397
# 3      IL  1613272441
# 4      PF  1613272400

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of Latitude vs. Max Temperature
fig, ax = plt.subplots(1, figsize=(7,5))
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"], color= 'steelblue', edgecolors= 'black')
plt.xlabel("Latitude", size=12)
plt.ylabel("Max Temperature (F)", size=12)
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%m/%d/%Y')})", size=14)
ax.grid()
plt.savefig("Latitude vs Temperature")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate a scatter plot of Latitude vs. Humidity
fig, ax = plt.subplots(1, figsize=(7,5))
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"], color= 'steelblue', edgecolors= 'black')
plt.xlabel("Latitude", size=12)
plt.ylabel("Humidity (%)", size=12)
plt.title(f"City Latitude vs Humidity ({time.strftime('%m/%d/%Y')})", size=14)
ax.grid()
plt.savefig("City Latitude vs Humidity")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot of Latitude vs. Cloudiness
fig, ax = plt.subplots(1, figsize=(7,5))
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"], color= 'steelblue', edgecolors= 'black')
plt.xlabel("Latitude", size=12)
plt.ylabel("Cloudiness (%)", size=12)
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%m/%d/%Y')})", size=14)
ax.grid()
plt.savefig("Latitude vs Cloudiness")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot of Latitude vs. Wind Speed
fig, ax = plt.subplots(1, figsize=(7,5))
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind Speed"], color= 'steelblue', edgecolors= 'black')
plt.xlabel("Latitude", size=12)
plt.ylabel("Wind Speed (mph)", size=12)
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%m/%d/%Y')})", size=14)
ax.grid()
plt.savefig("Latitude vs Wind Speed")

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
